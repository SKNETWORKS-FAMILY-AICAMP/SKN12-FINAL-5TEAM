# %%
import pandas as pd
from tqdm import tqdm
from autogluon.tabular import TabularDataset, TabularPredictor
import json
import numpy as np
import os

# 데이터 경로 (os.path.join 사용, 절대 경로)
BASE_DIR = os.getcwd()
print(BASE_DIR)
INPUT_FILE_PATH = os.path.join(BASE_DIR, 'data', 'preprocessed_data.json')
DATA_DIR = os.path.join(BASE_DIR, 'data', 'ML')
os.makedirs(DATA_DIR, exist_ok=True)
# Out:
# c:\final_git\SKN12-FINAL-5TEAM

# %% [markdown]
# ## json 파일을 데이터프레임으로 변환

# %% [markdown]
# ## ML에 입력할 수 있도록 독립 / 종속 변수 추가

# %%
# npz 불러오기
train = np.load(os.path.join(DATA_DIR, "train_set.npz"))
X_train = train["X"]
y_train = train["y"]

# 컬럼 이름 만들기
n_features = X_train.shape[1]
feature_columns = [f"f{i}" for i in range(n_features)]

# DataFrame 생성
df_train = pd.DataFrame(X_train, columns=feature_columns)
df_train["score"] = y_train # 종속변수 추가

val = np.load(os.path.join(DATA_DIR, "val_set.npz"))
X_val = val["X"]
y_val = val["y"]
df_val = pd.DataFrame(X_val, columns=feature_columns)
df_val["score"] = y_val # 종속변수 추가

test = np.load(os.path.join(DATA_DIR, "test_set.npz"))
X_test = test["X"]
y_test = test["y"]
df_test = pd.DataFrame(X_test, columns=feature_columns)
df_test["score"] = y_test # 종속변수 추가


train_data = TabularDataset(df_train)
val_data = TabularDataset(df_val)
test_data = TabularDataset(df_test)

# %%
train_data.head()
# Out:
#          f0        f1        f2        f3        f4        f5        f6  \
# 0 -0.454308 -0.191012  0.079864 -0.534569 -0.068804  0.017660  0.224310
# 1  0.006021 -0.706709 -0.360626 -0.347866  0.355289  0.699073 -0.213558
# 2 -0.197276 -0.294467  0.414493 -0.373786  0.317888  0.066508 -0.189156
# 3  0.208798 -0.105023 -0.051948 -0.191882  0.193627 -0.091749  0.241087
# 4 -0.112501 -0.304849 -0.043498 -0.297551  0.484919 -0.212221  0.086554
#
#          f7        f8        f9  ...     f1527     f1528     f1529     f1530  \
# 0 -0.269141 -0.361705  0.053733  ...  0.491733  0.359190 -0.123756 -0.515413
# 1  0.278139 -0.362823  0.273964  ...  0.746505  0.164486 -0.271899  0.004447
# 2  0.228830 -0.402630  0.703705  ...  0.317407  0.204780 -0.016202 -0.265335
# 3  0.238545  0.159051  0.491462  ...  0.609287  0.674161 -0.049371  0.001968
# 4 -0.089514 -0.218532  0.533597  ...  1.009515  0.507447  0.081017  0.218226
#
#       f1531     f1532     f1533     f1534     f1535    score
# 0  0.105428  0.175339  0.072150 -0.036318 -0.250155  48.7933
# 1  0.757929 -0.417573  0.060278 -0.676335 -0.297556  48.3933
# 2  0.574012 -0.274860 -0.171743 -0.043548 -0.318174  51.4933
# 3  0.019721 -0.094569 -0.111176 -0.318199 -0.488020  43.9800
# 4  0.862200 -0.710890  0.140288 -0.419778  0.308251  47.0967
#
# [5 rows x 1537 columns]

# %% [markdown]
# ## AutoML 설정

# %%
from autogluon.tabular import TabularPredictor

predictor = TabularPredictor(
    label='score',
    path='automl/',
    problem_type='regression',
    eval_metric='rmse'  # 💡 평가 지표를 RMSE로 설정
).fit(
    train_data=train_data,
    tuning_data=val_data,       # 💡 검증 데이터 명시
    time_limit=600
)

# 평가: 여러 지표 다 나옴
results = predictor.evaluate(test_data)

# 출력
for metric, value in results.items():
    print(f"{metric}: {value}")
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="automl/"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.3.1
# Python Version:     3.10.18
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          16
# Memory Avail:       12.44 GB / 31.64 GB (39.3%)
# Disk Space Avail:   256.49 GB / 476.00 GB (53.9%)
# ===================================================
# No presets specified! To achieve strong results with AutoGluon, it is recommended to use the available presets. Defaulting to `'medium'`...
# 	Recommended Presets (For more details refer to https://auto.gluon.ai/stable/tutorials/tabular/tabular-essentials.html#presets):
# 	presets='experimental' : New in v1.2: Pre-trained foundation model + parallel fits. The absolute best accuracy without consideration for inference speed. Does not support GPU.
# 	presets='best'         : Maximize accuracy. Recommended for most users. Use in competitions and benchmarks.
# 	presets='high'         : Strong accuracy with fast inference speed.
# 	presets='good'         : Good accuracy with very fast inference speed.
# 	presets='medium'       : Fast training time, ideal for initial prototyping.
# Beginning AutoGluon training ... Time limit = 600s
# AutoGluon will save models to "c:\final_git\SKN12-FINAL-5TEAM\automl"
# Train Data Rows:    5257
# Train Data Columns: 1536
# Tuning Data Rows:    657
# Tuning Data Columns: 1536
# Label Column:       score
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    12703.62 MB
# 	Train Data (Original)  Memory Usage: 34.65 MB (0.3% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 3
#       1 from autogluon.tabular import TabularPredictor
# ----> 3 predictor = TabularPredictor(
#       4     label='score',
#       5     path='automl/',
#       6     problem_type='regression',
#       7     eval_metric='rmse'  # 💡 평가 지표를 RMSE로 설정
#       8 ).fit(
#       9     train_data=train_data,
#      10     tuning_data=val_data,       # 💡 검증 데이터 명시
#      11     time_limit=600
#      12 )
#      14 # 평가: 여러 지표 다 나옴
#      15 results = predictor.evaluate(test_data)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\core\utils\decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\predictor\predictor.py:1301, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, fit_full_last_level_weighted_ensemble, full_weighted_ensemble_additionally, dynamic_stacking, calibrate_decision_threshold, num_cpus, num_gpus, fit_strategy, memory_limit, callbacks, **kwargs)
#    1298 # keep track of the fit strategy used for future calls
#    1299 self._fit_strategy = fit_strategy
# -> 1301 self._fit(ag_fit_kwargs=ag_fit_kwargs, ag_post_fit_kwargs=ag_post_fit_kwargs)
#    1303 return self
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\predictor\predictor.py:1307, in TabularPredictor._fit(self, ag_fit_kwargs, ag_post_fit_kwargs)
#    1305 def _fit(self, ag_fit_kwargs: dict, ag_post_fit_kwargs: dict):
#    1306     self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# -> 1307     self._learner.fit(**ag_fit_kwargs)
#    1308     self._set_post_fit_vars()
#    1309     self._post_fit(**ag_post_fit_kwargs)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\learner\abstract_learner.py:159, in AbstractTabularLearner.fit(self, X, X_val, **kwargs)
#     157     raise AssertionError("Learner is already fit.")
#     158 self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 159 return self._fit(X=X, X_val=X_val, **kwargs)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\learner\default_learner.py:95, in DefaultLearner._fit(self, X, X_val, X_test, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, raise_on_model_failure, **trainer_fit_kwargs)
#      93 X_og = None if infer_limit_batch_size is None else X
#      94 logger.log(20, "Preprocessing data ...")
# ---> 95 X, y, X_val, y_val, X_test, y_test, X_unlabeled, holdout_frac, num_bag_folds, groups = self.general_data_processing(
#      96     X=X, X_val=X_val, X_test=X_test, X_unlabeled=X_unlabeled, holdout_frac=holdout_frac, num_bag_folds=num_bag_folds
#      97 )
#      98 if X_og is not None:
#      99     infer_limit = self._update_infer_limit(X=X_og, infer_limit_batch_size=infer_limit_batch_size, infer_limit=infer_limit)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\learner\default_learner.py:283, in DefaultLearner.general_data_processing(self, X, X_val, X_test, X_unlabeled, holdout_frac, num_bag_folds)
#     281 y_list = [y, y_val, y_test_super, y_unlabeled]
#     282 y_super = pd.concat(y_list, ignore_index=True)
# --> 283 X_super = self.fit_transform_features(X_super, y_super, problem_type=self.label_cleaner.problem_type_transform, eval_metric=self.eval_metric)
#     284 if not transform_with_test and X_test is not None:
#     285     X_test = self.feature_generator.transform(X_test)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\tabular\learner\abstract_learner.py:483, in AbstractTabularLearner.fit_transform_features(self, X, y, **kwargs)
#     481     X = X.drop(columns=self.ignored_columns, errors="ignore")
#     482 for feature_generator in self.feature_generators:
# --> 483     X = feature_generator.fit_transform(X, y, **kwargs)
#     484 return X
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\pipeline.py:70, in PipelineFeatureGenerator.fit_transform(self, X, y, feature_metadata_in, **kwargs)
#      69 def fit_transform(self, X: DataFrame, y=None, feature_metadata_in: FeatureMetadata = None, **kwargs) -> DataFrame:
# ---> 70     X_out = super().fit_transform(X=X, y=y, feature_metadata_in=feature_metadata_in, **kwargs)
#      71     self._compute_post_memory_usage(X_out)
#      72     # TODO: Consider adding final check of validity/that features are reasonable.
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\abstract.py:290, in AbstractFeatureGenerator.fit_transform(self, X, y, feature_metadata_in, **kwargs)
#     286     self._pre_astype_generator.fit(X)
#     288 # TODO: Add option to return feature_metadata instead to avoid data copy
#     289 #  If so, consider adding validation step to check that X_out matches the feature metadata, error/warning if not
# --> 290 X_out, type_family_groups_special = self._fit_transform(X[self.features_in], y=y, **kwargs)
#     292 type_map_raw = get_type_map_raw(X_out)
#     293 self._feature_metadata_before_post = FeatureMetadata(
#     294     type_map_raw=type_map_raw, type_group_map_special=type_family_groups_special
#     295 )
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\pipeline.py:77, in PipelineFeatureGenerator._fit_transform(self, X, y, **kwargs)
#      76 def _fit_transform(self, X: DataFrame, y=None, **kwargs):
# ---> 77     X_out, type_group_map_special = super()._fit_transform(X=X, y=y, **kwargs)
#      78     X_out, type_group_map_special = self._fit_transform_custom(
#      79         X_out=X_out, type_group_map_special=type_group_map_special, y=y
#      80     )
#      81     return X_out, type_group_map_special
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\bulk.py:141, in BulkFeatureGenerator._fit_transform(self, X, **kwargs)
#     139         generator.verbosity = self.verbosity
#     140     generator.set_log_prefix(log_prefix=self.log_prefix + "\t\t", prepend=True)
# --> 141     feature_df_list.append(generator.fit_transform(X, feature_metadata_in=feature_metadata, **kwargs))
#     142     generator_group_valid.append(generator)
#     143 else:
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\abstract.py:273, in AbstractFeatureGenerator.fit_transform(self, X, y, feature_metadata_in, **kwargs)
#     271         self.column_names_as_str = False  # Columns were already string, so don't do conversion. Better to error if they change types at inference.
#     272 self._ensure_no_duplicate_column_names(X=X)
# --> 273 self._infer_features_in_full(X=X, feature_metadata_in=feature_metadata_in)
#     274 if self.pre_drop_useless:
#     275     self._useless_features_in = self._get_useless_features(X, columns_to_check=self.features_in)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\features\generators\abstract.py:462, in AbstractFeatureGenerator._infer_features_in_full(self, X, feature_metadata_in)
#     460     self.features_in = self._infer_features_in(X=X)
#     461     self.features_in = [feature for feature in self.features_in if feature in X.columns]
# --> 462 self.feature_metadata_in = self.feature_metadata_in.keep_features(features=self.features_in)
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\common\features\feature_metadata.py:245, in FeatureMetadata.keep_features(self, features, inplace)
#     243 def keep_features(self, features: list, inplace=False):
#     244     """Removes all features from metadata except for those in features"""
# --> 245     features_invalid = [feature for feature in features if feature not in self.get_features()]
#     246     if features_invalid:
#     247         raise KeyError(
#     248             f"keep_features was called with a feature that does not exist in feature metadata. Invalid Features: {features_invalid}"
#     249         )
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\common\features\feature_metadata.py:245, in <listcomp>(.0)
#     243 def keep_features(self, features: list, inplace=False):
#     244     """Removes all features from metadata except for those in features"""
# --> 245     features_invalid = [feature for feature in features if feature not in self.get_features()]
#     246     if features_invalid:
#     247         raise KeyError(
#     248             f"keep_features was called with a feature that does not exist in feature metadata. Invalid Features: {features_invalid}"
#     249         )
#
# File c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\autogluon\common\features\feature_metadata.py:144, in FeatureMetadata.get_features(self, valid_raw_types, valid_special_types, invalid_raw_types, invalid_special_types, required_special_types, required_raw_special_pairs, required_exact, required_at_least_one_special)
#     101 """
#     102 Returns a list of features held within the feature metadata object after being pruned through the available parameters.
#     103
#    (...)
#     140
#     141 """
#     142 features = list(self.type_map_raw.keys())
# --> 144 if valid_raw_types is not None:
#     145     features = [feature for feature in features if self.get_feature_type_raw(feature) in valid_raw_types]
#     146 if valid_special_types is not None:
#
# KeyboardInterrupt:

# %%
# 학습된 모델들의 성능을 확인합니다.
leaderboard = predictor.leaderboard(test_data, silent=True)
leaderboard
# Out:
#                  model  score_test  score_val              eval_metric  \
# 0           LightGBMXT   -6.695962  -6.228672  root_mean_squared_error
# 1  WeightedEnsemble_L2   -6.695962  -6.228672  root_mean_squared_error
# 2             LightGBM   -6.808247  -6.343531  root_mean_squared_error
# 3      RandomForestMSE   -7.336781  -6.705860  root_mean_squared_error
# 4       KNeighborsDist   -8.150046  -7.541428  root_mean_squared_error
# 5       KNeighborsUnif   -8.179447  -7.577029  root_mean_squared_error
#
#    pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  \
# 0        0.039003       0.028000   30.880543                 0.039003
# 1        0.060009       0.028000   30.896077                 0.021006
# 2        0.042011       0.026005   36.285259                 0.042011
# 3        0.344626       0.194681  620.611826                 0.344626
# 4        1.244310       1.029261    0.450217                 1.244310
# 5        1.135977       0.984943    0.516378                 1.135977
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.028000          30.880543            1       True
# 1                0.000000           0.015533            2       True
# 2                0.026005          36.285259            1       True
# 3                0.194681         620.611826            1       True
# 4                1.029261           0.450217            1       True
# 5                0.984943           0.516378            1       True
#
#    fit_order
# 0          3
# 1          6
# 2          4
# 3          5
# 4          2
# 5          1

# %%
# 리더보드에서 모델명과 테스트 점수만 표시
leaderboard_simple = leaderboard[['model', 'score_test']].copy()
leaderboard_simple
# Out:
#                  model  score_test
# 0           LightGBMXT   -6.695962
# 1  WeightedEnsemble_L2   -6.695962
# 2             LightGBM   -6.808247
# 3      RandomForestMSE   -7.336781
# 4       KNeighborsDist   -8.150046
# 5       KNeighborsUnif   -8.179447

# %%
from autogluon.tabular import TabularPredictor
from sklearn.metrics import mean_absolute_error, r2_score # r2_score 임포트 추가

# 모델이 저장된 경로
model_path = 'automl/' # 

# 모델 불러오기
predictor = TabularPredictor.load(model_path)

# 예측 값 (클래스 값)
y_pred = predictor.predict(test_data)

overall_r2 = r2_score(test_data['score'], y_pred)
print(overall_r2)
# Out:
# 0.4538397177818283

# %%
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd
import numpy as np

# 예측값 계산 (AutoGluon predictor 썼다면)
y_pred = predictor.predict(test_data)

# 실제값
y_true = test_data['score']  # 또는 y_test

# RMSE, R2 계산
rmse = mean_squared_error(y_true, y_pred, squared=False)
r2 = r2_score(y_true, y_pred)

# 데이터프레임 형태로 보기 좋게 출력
df_metrics = pd.DataFrame({
    "지표": ["RMSE", "R² Score"],
    "값": [round(rmse, 3), round(r2, 3)]
})

import IPython.display as dsp
dsp.display(df_metrics)
# Out:
# c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#          지표      값
# 0      RMSE  6.696
# 1  R² Score  0.454

# %%
from sklearn.metrics import mean_squared_error, r2_score
import pandas as pd

# 상위 3개 모델 이름 가져오기
top_3_models = leaderboard['model'].head(3).tolist()

# 결과를 저장할 리스트
results = []

for model_name in top_3_models:
    # 각 모델로 예측
    y_pred = predictor.predict(test_data, model=model_name)
    y_true = test_data['score']
    
    # RMSE, R2 계산
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    r2 = r2_score(y_true, y_pred)
    
    results.append({
        '모델명': model_name,
        'RMSE': round(rmse, 4),
        'R² Score': round(r2, 4)
    })

# 데이터프레임으로 변환하여 표 형태로 출력
df_results = pd.DataFrame(results)
print("상위 3개 모델 성능 비교:")
df_results
# Out:
# 상위 3개 모델 성능 비교:
# c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# c:\Users\Playdata\AppData\Local\miniconda3\envs\mo\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#                    모델명    RMSE  R² Score
# 0  WeightedEnsemble_L2  6.6960    0.4538
# 1           LightGBMXT  6.6960    0.4538
# 2             LightGBM  6.8082    0.4354
